# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 3. Create a new set of 2,000 random latitudes and longitudes.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ### 4. Get the nearest city using the citipy module.

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 718

# %% [markdown]
# ### 5. Perform an API call with the OpenWeatherMap.
# ...
# ### 6. Retrieve the following information from the API call:
# - Latitude and longitude
# - Maximum temperature
# - Percent humidity
# - Percent cloudiness
# - Wind speed
# - Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # FIRST: Isolate  "weather" for easy reading
        # THEN: Retrieve the city's description
        step_1 = city_weather["weather"]
        city_description = step_1[0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_description})
                          #"Date": city_date
                          

        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | omboue
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | aswan
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | ribeira grande
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | iqaluit
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | henties bay
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | porto novo
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | cidreira
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 1 | husavik
# Processing Record 18 of Set 1 | warwick
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | labuhan
# Processing Record 26 of Set 1 | sindand
# City not found. Skipping...
# Processing Record 27 of Set 1 | geraldton
# Processing Record 28 of Set 1 | bandarbeyla
# Processing Record 29 of Set 1 | nemuro
# Processing Record 30 of Set 1 | ambovombe
# Processing Record 31 of Set 1 | gondanglegi
# Processing Record 32 of Set 1 | doha
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | ewa beach
# Processing Record 35 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | katherine
# Processing Record 38 of Set 1 | bengkulu
# Processing Record 39 of Set 1 | mount isa
# Processing Record 40 of Set 1 | chuy
# Processing Record 41 of Set 1 | lavra
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | yaan
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | moshkovo
# Processing Record 46 of Set 1 | pevek
# Processing Record 47 of Set 1 | san rafael
# Processing Record 48 of Set 1 | krivosheino
# Processing Record 49 of Set 1 | sao miguel do tapuio
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | sao joao da barra
# Processing Record 2 of Set 2 | saint george
# Processing Record 3 of Set 2 | dikson
# Processing Record 4 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | atuona
# Processing Record 7 of Set 2 | say
# Processing Record 8 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 2 | mantua
# Processing Record 10 of Set 2 | jarvenpaa
# Processing Record 11 of Set 2 | pangody
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | kishi
# Processing Record 14 of Set 2 | malim
# Processing Record 15 of Set 2 | shingu
# Processing Record 16 of Set 2 | sembe
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | kargasok
# Processing Record 19 of Set 2 | bowen
# Processing Record 20 of Set 2 | karaton
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | sinnamary
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | vanimo
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | nalut
# Processing Record 27 of Set 2 | lebu
# Processing Record 28 of Set 2 | mount gambier
# Processing Record 29 of Set 2 | ilulissat
# Processing Record 30 of Set 2 | opole
# Processing Record 31 of Set 2 | kiruna
# Processing Record 32 of Set 2 | hamilton
# Processing Record 33 of Set 2 | nome
# Processing Record 34 of Set 2 | boa vista
# Processing Record 35 of Set 2 | petukhovo
# Processing Record 36 of Set 2 | touros
# Processing Record 37 of Set 2 | the valley
# Processing Record 38 of Set 2 | castro
# Processing Record 39 of Set 2 | mayo
# Processing Record 40 of Set 2 | yaring
# Processing Record 41 of Set 2 | slave lake
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | riyadh
# Processing Record 44 of Set 2 | lata
# Processing Record 45 of Set 2 | arraial do cabo
# Processing Record 46 of Set 2 | kuching
# Processing Record 47 of Set 2 | cabo san lucas
# Processing Record 48 of Set 2 | smithers
# Processing Record 49 of Set 2 | avera
# Processing Record 50 of Set 2 | cherskiy
# Processing Record 1 of Set 3 | kaitangata
# Processing Record 2 of Set 3 | vila franca do campo
# Processing Record 3 of Set 3 | saint-pierre
# Processing Record 4 of Set 3 | kodiak
# Processing Record 5 of Set 3 | waipawa
# Processing Record 6 of Set 3 | kalmunai
# Processing Record 7 of Set 3 | jiuquan
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | kavaratti
# Processing Record 10 of Set 3 | sunndalsora
# Processing Record 11 of Set 3 | leshukonskoye
# Processing Record 12 of Set 3 | vanavara
# Processing Record 13 of Set 3 | banepa
# Processing Record 14 of Set 3 | hermanus
# Processing Record 15 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 3 | half moon bay
# Processing Record 17 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 3 | vardo
# Processing Record 19 of Set 3 | hualmay
# Processing Record 20 of Set 3 | lagoa
# Processing Record 21 of Set 3 | torbay
# Processing Record 22 of Set 3 | bozeman
# Processing Record 23 of Set 3 | esperance
# Processing Record 24 of Set 3 | dubai
# Processing Record 25 of Set 3 | lavrentiya
# Processing Record 26 of Set 3 | hithadhoo
# Processing Record 27 of Set 3 | xuddur
# Processing Record 28 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 3 | bluff
# Processing Record 30 of Set 3 | eston
# Processing Record 31 of Set 3 | catabola
# Processing Record 32 of Set 3 | darhan
# Processing Record 33 of Set 3 | shimoda
# Processing Record 34 of Set 3 | tiksi
# Processing Record 35 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 3 | port blair
# Processing Record 37 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 3 | bethel
# Processing Record 39 of Set 3 | gazanjyk
# Processing Record 40 of Set 3 | oum hadjer
# Processing Record 41 of Set 3 | dunedin
# Processing Record 42 of Set 3 | la ronge
# Processing Record 43 of Set 3 | te anau
# Processing Record 44 of Set 3 | lompoc
# Processing Record 45 of Set 3 | kiomboi
# Processing Record 46 of Set 3 | berdigestyakh
# Processing Record 47 of Set 3 | clyde river
# Processing Record 48 of Set 3 | novopokrovka
# Processing Record 49 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 4 | butaritari
# Processing Record 2 of Set 4 | katsuura
# Processing Record 3 of Set 4 | batagay-alyta
# Processing Record 4 of Set 4 | pushkino
# Processing Record 5 of Set 4 | upington
# Processing Record 6 of Set 4 | inhambane
# Processing Record 7 of Set 4 | havelock
# Processing Record 8 of Set 4 | bredasdorp
# Processing Record 9 of Set 4 | denpasar
# Processing Record 10 of Set 4 | brikama
# Processing Record 11 of Set 4 | batagay
# Processing Record 12 of Set 4 | sindgi
# Processing Record 13 of Set 4 | hargeysa
# Processing Record 14 of Set 4 | khatanga
# Processing Record 15 of Set 4 | qasigiannguit
# Processing Record 16 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 17 of Set 4 | bennington
# Processing Record 18 of Set 4 | zhangye
# Processing Record 19 of Set 4 | norman wells
# Processing Record 20 of Set 4 | suifenhe
# Processing Record 21 of Set 4 | pacific grove
# Processing Record 22 of Set 4 | northam
# Processing Record 23 of Set 4 | marsh harbour
# Processing Record 24 of Set 4 | manggar
# Processing Record 25 of Set 4 | san patricio
# Processing Record 26 of Set 4 | burnsville
# Processing Record 27 of Set 4 | krasnoarmeysk
# Processing Record 28 of Set 4 | guerrero negro
# Processing Record 29 of Set 4 | carnarvon
# Processing Record 30 of Set 4 | nikolskoye
# Processing Record 31 of Set 4 | haines junction
# Processing Record 32 of Set 4 | lorengau
# Processing Record 33 of Set 4 | flinders
# Processing Record 34 of Set 4 | ola
# Processing Record 35 of Set 4 | saint-philippe
# Processing Record 36 of Set 4 | bestobe
# Processing Record 37 of Set 4 | sturgeon falls
# Processing Record 38 of Set 4 | guelph
# Processing Record 39 of Set 4 | tiznit
# Processing Record 40 of Set 4 | tivaouane
# Processing Record 41 of Set 4 | caucaia
# Processing Record 42 of Set 4 | novikovo
# Processing Record 43 of Set 4 | charters towers
# Processing Record 44 of Set 4 | pangnirtung
# Processing Record 45 of Set 4 | sitka
# Processing Record 46 of Set 4 | hovd
# Processing Record 47 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 4 | tooele
# Processing Record 49 of Set 4 | miraflores
# Processing Record 50 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 5 | rawson
# Processing Record 2 of Set 5 | garcia
# Processing Record 3 of Set 5 | saint anthony
# Processing Record 4 of Set 5 | wattegama
# Processing Record 5 of Set 5 | santa isabel do rio negro
# Processing Record 6 of Set 5 | upernavik
# Processing Record 7 of Set 5 | vila velha
# Processing Record 8 of Set 5 | souillac
# Processing Record 9 of Set 5 | sur
# Processing Record 10 of Set 5 | bemidji
# Processing Record 11 of Set 5 | same
# Processing Record 12 of Set 5 | aklavik
# Processing Record 13 of Set 5 | eydhafushi
# Processing Record 14 of Set 5 | marawi
# Processing Record 15 of Set 5 | merauke
# Processing Record 16 of Set 5 | coihaique
# Processing Record 17 of Set 5 | kaeo
# Processing Record 18 of Set 5 | north battleford
# Processing Record 19 of Set 5 | saldanha
# Processing Record 20 of Set 5 | leningradskiy
# Processing Record 21 of Set 5 | hami
# Processing Record 22 of Set 5 | faanui
# Processing Record 23 of Set 5 | margate
# Processing Record 24 of Set 5 | gat
# Processing Record 25 of Set 5 | bar harbor
# Processing Record 26 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 27 of Set 5 | saint-augustin
# Processing Record 28 of Set 5 | moroni
# Processing Record 29 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 5 | east london
# Processing Record 31 of Set 5 | torata
# Processing Record 32 of Set 5 | richards bay
# Processing Record 33 of Set 5 | thinadhoo
# Processing Record 34 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 35 of Set 5 | pak phanang
# Processing Record 36 of Set 5 | nkhotakota
# Processing Record 37 of Set 5 | fethiye
# Processing Record 38 of Set 5 | requena
# Processing Record 39 of Set 5 | sao filipe
# Processing Record 40 of Set 5 | humberto de campos
# Processing Record 41 of Set 5 | ayan
# Processing Record 42 of Set 5 | warrington
# Processing Record 43 of Set 5 | pedernales
# Processing Record 44 of Set 5 | sioux lookout
# Processing Record 45 of Set 5 | alghero
# Processing Record 46 of Set 5 | havoysund
# Processing Record 47 of Set 5 | russell
# Processing Record 48 of Set 5 | kawalu
# Processing Record 49 of Set 5 | nioki
# Processing Record 50 of Set 5 | ixtapa
# Processing Record 1 of Set 6 | balatonfured
# Processing Record 2 of Set 6 | kombotion
# City not found. Skipping...
# Processing Record 3 of Set 6 | kloulklubed
# Processing Record 4 of Set 6 | karratha
# Processing Record 5 of Set 6 | ponta do sol
# Processing Record 6 of Set 6 | ottumwa
# Processing Record 7 of Set 6 | kruisfontein
# Processing Record 8 of Set 6 | cockburn town
# Processing Record 9 of Set 6 | whithorn
# Processing Record 10 of Set 6 | ketchikan
# Processing Record 11 of Set 6 | bilibino
# Processing Record 12 of Set 6 | goderich
# Processing Record 13 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 14 of Set 6 | viedma
# Processing Record 15 of Set 6 | nedjo
# Processing Record 16 of Set 6 | klaksvik
# Processing Record 17 of Set 6 | shulan
# Processing Record 18 of Set 6 | terra santa
# Processing Record 19 of Set 6 | elizabeth city
# Processing Record 20 of Set 6 | victoria
# Processing Record 21 of Set 6 | verkhnyaya inta
# Processing Record 22 of Set 6 | yarensk
# Processing Record 23 of Set 6 | villazon
# Processing Record 24 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 25 of Set 6 | tromso
# Processing Record 26 of Set 6 | maridi
# Processing Record 27 of Set 6 | yurginskoye
# Processing Record 28 of Set 6 | mahon
# Processing Record 29 of Set 6 | veraval
# Processing Record 30 of Set 6 | zhoucheng
# Processing Record 31 of Set 6 | hasaki
# Processing Record 32 of Set 6 | ancud
# Processing Record 33 of Set 6 | catamarca
# Processing Record 34 of Set 6 | praia da vitoria
# Processing Record 35 of Set 6 | loa janan
# Processing Record 36 of Set 6 | ambilobe
# Processing Record 37 of Set 6 | padang
# Processing Record 38 of Set 6 | kieta
# Processing Record 39 of Set 6 | nakamura
# Processing Record 40 of Set 6 | kahului
# Processing Record 41 of Set 6 | bayburt
# Processing Record 42 of Set 6 | potam
# Processing Record 43 of Set 6 | palmerston
# Processing Record 44 of Set 6 | harrisburg
# Processing Record 45 of Set 6 | caravelas
# Processing Record 46 of Set 6 | baykit
# Processing Record 47 of Set 6 | filingue
# Processing Record 48 of Set 6 | hurghada
# Processing Record 49 of Set 6 | luderitz
# Processing Record 50 of Set 6 | kasongo-lunda
# Processing Record 1 of Set 7 | vao
# Processing Record 2 of Set 7 | pemba
# Processing Record 3 of Set 7 | kenora
# Processing Record 4 of Set 7 | nchelenge
# Processing Record 5 of Set 7 | evensk
# Processing Record 6 of Set 7 | birjand
# Processing Record 7 of Set 7 | cap malheureux
# Processing Record 8 of Set 7 | safford
# Processing Record 9 of Set 7 | mogadishu
# Processing Record 10 of Set 7 | santa maria
# Processing Record 11 of Set 7 | hit
# Processing Record 12 of Set 7 | luzhou
# Processing Record 13 of Set 7 | gushikawa
# Processing Record 14 of Set 7 | calbuco
# Processing Record 15 of Set 7 | yuzhne
# Processing Record 16 of Set 7 | moron
# Processing Record 17 of Set 7 | tura
# Processing Record 18 of Set 7 | tecoanapa
# Processing Record 19 of Set 7 | talnakh
# Processing Record 20 of Set 7 | broome
# Processing Record 21 of Set 7 | talakan
# Processing Record 22 of Set 7 | rocha
# Processing Record 23 of Set 7 | mahebourg
# Processing Record 24 of Set 7 | aykhal
# Processing Record 25 of Set 7 | jiexiu
# Processing Record 26 of Set 7 | nanortalik
# Processing Record 27 of Set 7 | gangotri
# City not found. Skipping...
# Processing Record 28 of Set 7 | honiara
# Processing Record 29 of Set 7 | tezu
# Processing Record 30 of Set 7 | altamont
# Processing Record 31 of Set 7 | macklin
# Processing Record 32 of Set 7 | san jose
# Processing Record 33 of Set 7 | san antonio
# Processing Record 34 of Set 7 | terme
# Processing Record 35 of Set 7 | belousovka
# Processing Record 36 of Set 7 | nizhniy kuranakh
# Processing Record 37 of Set 7 | shaki
# Processing Record 38 of Set 7 | ridgecrest
# Processing Record 39 of Set 7 | tukrah
# Processing Record 40 of Set 7 | puerto colombia
# Processing Record 41 of Set 7 | vermilion
# Processing Record 42 of Set 7 | naruto
# Processing Record 43 of Set 7 | eureka
# Processing Record 44 of Set 7 | santa cruz de tenerife
# Processing Record 45 of Set 7 | wuwei
# Processing Record 46 of Set 7 | okhotsk
# Processing Record 47 of Set 7 | airai
# Processing Record 48 of Set 7 | durazno
# Processing Record 49 of Set 7 | jaru
# Processing Record 50 of Set 7 | zyryanka
# Processing Record 1 of Set 8 | thompson
# Processing Record 2 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 8 | kontagora
# Processing Record 4 of Set 8 | saint-francois
# Processing Record 5 of Set 8 | axim
# Processing Record 6 of Set 8 | pathein
# Processing Record 7 of Set 8 | vadso
# Processing Record 8 of Set 8 | nyimba
# Processing Record 9 of Set 8 | le port
# Processing Record 10 of Set 8 | cabedelo
# Processing Record 11 of Set 8 | luino
# Processing Record 12 of Set 8 | jaque
# Processing Record 13 of Set 8 | yar-sale
# Processing Record 14 of Set 8 | kamenka
# Processing Record 15 of Set 8 | kismayo
# Processing Record 16 of Set 8 | faya
# Processing Record 17 of Set 8 | pisco
# Processing Record 18 of Set 8 | laguna
# Processing Record 19 of Set 8 | vigrestad
# Processing Record 20 of Set 8 | myitkyina
# Processing Record 21 of Set 8 | tyshkivka
# Processing Record 22 of Set 8 | altay
# Processing Record 23 of Set 8 | pincher creek
# Processing Record 24 of Set 8 | listvyanka
# Processing Record 25 of Set 8 | santiago del estero
# Processing Record 26 of Set 8 | hambantota
# Processing Record 27 of Set 8 | naze
# Processing Record 28 of Set 8 | mandvi
# Processing Record 29 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 8 | srednekolymsk
# Processing Record 31 of Set 8 | kavieng
# Processing Record 32 of Set 8 | linchuan
# City not found. Skipping...
# Processing Record 33 of Set 8 | biak
# Processing Record 34 of Set 8 | dinghai
# Processing Record 35 of Set 8 | qaqortoq
# Processing Record 36 of Set 8 | hokitika
# Processing Record 37 of Set 8 | motygino
# Processing Record 38 of Set 8 | luwuk
# Processing Record 39 of Set 8 | emba
# Processing Record 40 of Set 8 | mineros
# Processing Record 41 of Set 8 | kushiro
# Processing Record 42 of Set 8 | fare
# Processing Record 43 of Set 8 | bairiki
# Processing Record 44 of Set 8 | talaya
# Processing Record 45 of Set 8 | jalu
# Processing Record 46 of Set 8 | mitu
# Processing Record 47 of Set 8 | talcahuano
# Processing Record 48 of Set 8 | tazovskiy
# Processing Record 49 of Set 8 | palmer
# Processing Record 50 of Set 8 | san cristobal
# Processing Record 1 of Set 9 | bilma
# Processing Record 2 of Set 9 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 3 of Set 9 | pangkalanbuun
# Processing Record 4 of Set 9 | mildura
# Processing Record 5 of Set 9 | tautira
# Processing Record 6 of Set 9 | nizhniy tsasuchey
# Processing Record 7 of Set 9 | vestmannaeyjar
# Processing Record 8 of Set 9 | port elizabeth
# Processing Record 9 of Set 9 | fort nelson
# Processing Record 10 of Set 9 | puerto leguizamo
# Processing Record 11 of Set 9 | misratah
# Processing Record 12 of Set 9 | suar
# Processing Record 13 of Set 9 | casper
# Processing Record 14 of Set 9 | trincomalee
# Processing Record 15 of Set 9 | peniche
# Processing Record 16 of Set 9 | umm lajj
# Processing Record 17 of Set 9 | shenjiamen
# Processing Record 18 of Set 9 | kurud
# Processing Record 19 of Set 9 | chokurdakh
# Processing Record 20 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 9 | poronaysk
# Processing Record 22 of Set 9 | amurzet
# Processing Record 23 of Set 9 | los llanos de aridane
# Processing Record 24 of Set 9 | kudahuvadhoo
# Processing Record 25 of Set 9 | lamak
# Processing Record 26 of Set 9 | kasempa
# Processing Record 27 of Set 9 | codajas
# Processing Record 28 of Set 9 | zelenogorskiy
# Processing Record 29 of Set 9 | leh
# Processing Record 30 of Set 9 | nuuk
# Processing Record 31 of Set 9 | newport
# Processing Record 32 of Set 9 | steinfurt
# Processing Record 33 of Set 9 | cejkovice
# Processing Record 34 of Set 9 | hay river
# Processing Record 35 of Set 9 | christchurch
# Processing Record 36 of Set 9 | waupun
# Processing Record 37 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 38 of Set 9 | provideniya
# Processing Record 39 of Set 9 | yulara
# Processing Record 40 of Set 9 | longyearbyen
# Processing Record 41 of Set 9 | burica
# City not found. Skipping...
# Processing Record 42 of Set 9 | khani
# Processing Record 43 of Set 9 | nadadores
# Processing Record 44 of Set 9 | najran
# Processing Record 45 of Set 9 | chapais
# Processing Record 46 of Set 9 | morondava
# Processing Record 47 of Set 9 | kuopio
# Processing Record 48 of Set 9 | zhaotong
# Processing Record 49 of Set 9 | korla
# Processing Record 50 of Set 9 | salamanca
# Processing Record 1 of Set 10 | kollegal
# Processing Record 2 of Set 10 | tacuarembo
# Processing Record 3 of Set 10 | aquiraz
# Processing Record 4 of Set 10 | shirokiy
# Processing Record 5 of Set 10 | plettenberg bay
# Processing Record 6 of Set 10 | itarema
# Processing Record 7 of Set 10 | ondjiva
# Processing Record 8 of Set 10 | lasa
# Processing Record 9 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 10 of Set 10 | bathsheba
# Processing Record 11 of Set 10 | manthani
# Processing Record 12 of Set 10 | raudeberg
# Processing Record 13 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 14 of Set 10 | ajdabiya
# Processing Record 15 of Set 10 | japura
# Processing Record 16 of Set 10 | yushan
# Processing Record 17 of Set 10 | metro
# Processing Record 18 of Set 10 | chumikan
# Processing Record 19 of Set 10 | maceio
# Processing Record 20 of Set 10 | ostrovnoy
# Processing Record 21 of Set 10 | foxton
# Processing Record 22 of Set 10 | fortuna
# Processing Record 23 of Set 10 | pierre
# Processing Record 24 of Set 10 | novoilinsk
# Processing Record 25 of Set 10 | poum
# Processing Record 26 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 10 | abha
# Processing Record 28 of Set 10 | safaga
# Processing Record 29 of Set 10 | ongandjera
# Processing Record 30 of Set 10 | bam
# Processing Record 31 of Set 10 | muswellbrook
# Processing Record 32 of Set 10 | najibabad
# Processing Record 33 of Set 10 | alta floresta
# Processing Record 34 of Set 10 | lakes entrance
# Processing Record 35 of Set 10 | lotofaga
# Processing Record 36 of Set 10 | wellington
# Processing Record 37 of Set 10 | college
# Processing Record 38 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 39 of Set 10 | valdivia
# Processing Record 40 of Set 10 | gucheng
# Processing Record 41 of Set 10 | alvaraes
# Processing Record 42 of Set 10 | saravena
# Processing Record 43 of Set 10 | gimli
# Processing Record 44 of Set 10 | soe
# Processing Record 45 of Set 10 | kushnarenkovo
# Processing Record 46 of Set 10 | haljala
# Processing Record 47 of Set 10 | manicore
# Processing Record 48 of Set 10 | cayenne
# Processing Record 49 of Set 10 | marienburg
# Processing Record 50 of Set 10 | auki
# Processing Record 1 of Set 11 | krasnozerskoye
# Processing Record 2 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 11 | pauini
# Processing Record 4 of Set 11 | xacmaz
# Processing Record 5 of Set 11 | beian
# Processing Record 6 of Set 11 | faranah
# Processing Record 7 of Set 11 | morehead
# Processing Record 8 of Set 11 | soldotna
# Processing Record 9 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 10 of Set 11 | mitsamiouli
# Processing Record 11 of Set 11 | aden
# Processing Record 12 of Set 11 | mundo nuevo
# Processing Record 13 of Set 11 | port hardy
# Processing Record 14 of Set 11 | carutapera
# Processing Record 15 of Set 11 | sungaipenuh
# Processing Record 16 of Set 11 | zholymbet
# Processing Record 17 of Set 11 | gomel
# Processing Record 18 of Set 11 | coahuayana
# Processing Record 19 of Set 11 | vereya
# Processing Record 20 of Set 11 | karasburg
# Processing Record 21 of Set 11 | portland
# Processing Record 22 of Set 11 | akureyri
# Processing Record 23 of Set 11 | brae
# Processing Record 24 of Set 11 | manjacaze
# Processing Record 25 of Set 11 | yazd
# Processing Record 26 of Set 11 | aviles
# Processing Record 27 of Set 11 | andra
# Processing Record 28 of Set 11 | isangel
# Processing Record 29 of Set 11 | kedrovyy
# Processing Record 30 of Set 11 | fatick
# Processing Record 31 of Set 11 | berlevag
# Processing Record 32 of Set 11 | beringovskiy
# Processing Record 33 of Set 11 | ayr
# Processing Record 34 of Set 11 | lazaro cardenas
# Processing Record 35 of Set 11 | byron bay
# Processing Record 36 of Set 11 | tuatapere
# Processing Record 37 of Set 11 | sangar
# Processing Record 38 of Set 11 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 39 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 40 of Set 11 | pong
# Processing Record 41 of Set 11 | newala
# Processing Record 42 of Set 11 | dhanera
# Processing Record 43 of Set 11 | dhidhdhoo
# Processing Record 44 of Set 11 | port macquarie
# Processing Record 45 of Set 11 | port lincoln
# Processing Record 46 of Set 11 | naryan-mar
# Processing Record 47 of Set 11 | oxford
# Processing Record 48 of Set 11 | xai-xai
# Processing Record 49 of Set 11 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 50 of Set 11 | mbala
# Processing Record 1 of Set 12 | portel
# Processing Record 2 of Set 12 | murmashi
# Processing Record 3 of Set 12 | bambous virieux
# Processing Record 4 of Set 12 | ust-maya
# Processing Record 5 of Set 12 | georgiyevka
# Processing Record 6 of Set 12 | horta
# Processing Record 7 of Set 12 | laukaa
# Processing Record 8 of Set 12 | luba
# Processing Record 9 of Set 12 | chicama
# Processing Record 10 of Set 12 | champerico
# Processing Record 11 of Set 12 | clearwater
# Processing Record 12 of Set 12 | hope
# Processing Record 13 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 12 | elko
# Processing Record 15 of Set 12 | garden city
# Processing Record 16 of Set 12 | pizarro
# Processing Record 17 of Set 12 | espanola
# Processing Record 18 of Set 12 | sunland park
# Processing Record 19 of Set 12 | batouri
# Processing Record 20 of Set 12 | muisne
# Processing Record 21 of Set 12 | turmalina
# Processing Record 22 of Set 12 | antalaha
# Processing Record 23 of Set 12 | olinda
# Processing Record 24 of Set 12 | pecos
# Processing Record 25 of Set 12 | dongsheng
# Processing Record 26 of Set 12 | buala
# Processing Record 27 of Set 12 | xining
# Processing Record 28 of Set 12 | camacha
# Processing Record 29 of Set 12 | syracuse
# Processing Record 30 of Set 12 | ballina
# Processing Record 31 of Set 12 | burla
# Processing Record 32 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 33 of Set 12 | santa rosa
# Processing Record 34 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 35 of Set 12 | dire dawa
# Processing Record 36 of Set 12 | hutchinson
# Processing Record 37 of Set 12 | gornopravdinsk
# Processing Record 38 of Set 12 | tateyama
# Processing Record 39 of Set 12 | belyy yar
# Processing Record 40 of Set 12 | high rock
# Processing Record 41 of Set 12 | chas
# Processing Record 42 of Set 12 | kirakira
# Processing Record 43 of Set 12 | bundaberg
# Processing Record 44 of Set 12 | hirara
# Processing Record 45 of Set 12 | cibitoke
# Processing Record 46 of Set 12 | sao miguel do araguaia
# Processing Record 47 of Set 12 | iquique
# Processing Record 48 of Set 12 | shakiso
# Processing Record 49 of Set 12 | nanpara
# Processing Record 50 of Set 12 | paamiut
# Processing Record 1 of Set 13 | oktyabrskiy
# Processing Record 2 of Set 13 | fairbanks
# Processing Record 3 of Set 13 | exu
# Processing Record 4 of Set 13 | conakry
# Processing Record 5 of Set 13 | ferkessedougou
# Processing Record 6 of Set 13 | alugan
# Processing Record 7 of Set 13 | porto nacional
# Processing Record 8 of Set 13 | praia
# Processing Record 9 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 10 of Set 13 | huarmey
# Processing Record 11 of Set 13 | murzzuschlag
# Processing Record 12 of Set 13 | rio grande
# Processing Record 13 of Set 13 | gamba
# Processing Record 14 of Set 13 | lucea
# Processing Record 15 of Set 13 | sao borja
# Processing Record 16 of Set 13 | hobyo
# Processing Record 17 of Set 13 | belaya gora
# Processing Record 18 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 13 | bayir
# Processing Record 20 of Set 13 | san ramon
# Processing Record 21 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 13 | sistranda
# Processing Record 23 of Set 13 | usinsk
# Processing Record 24 of Set 13 | songjianghe
# Processing Record 25 of Set 13 | puerto del rosario
# Processing Record 26 of Set 13 | ziro
# Processing Record 27 of Set 13 | kichera
# Processing Record 28 of Set 13 | visby
# Processing Record 29 of Set 13 | stephenville
# Processing Record 30 of Set 13 | chemal
# Processing Record 31 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 13 | rovaniemi
# Processing Record 33 of Set 13 | nordfjordeid
# Processing Record 34 of Set 13 | lamar
# Processing Record 35 of Set 13 | beloha
# Processing Record 36 of Set 13 | malakal
# Processing Record 37 of Set 13 | rumoi
# Processing Record 38 of Set 13 | namibe
# Processing Record 39 of Set 13 | aguada de pasajeros
# Processing Record 40 of Set 13 | meulaboh
# Processing Record 41 of Set 13 | taltal
# Processing Record 42 of Set 13 | setermoen
# Processing Record 43 of Set 13 | alamos
# Processing Record 44 of Set 13 | daru
# Processing Record 45 of Set 13 | manakara
# Processing Record 46 of Set 13 | brownfield
# Processing Record 47 of Set 13 | tommot
# Processing Record 48 of Set 13 | colquechaca
# Processing Record 49 of Set 13 | westport
# Processing Record 50 of Set 13 | quatre cocos
# Processing Record 1 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 3 of Set 14 | minden
# Processing Record 4 of Set 14 | farmington
# Processing Record 5 of Set 14 | jaciara
# Processing Record 6 of Set 14 | hillsborough
# Processing Record 7 of Set 14 | sunbury
# Processing Record 8 of Set 14 | uige
# Processing Record 9 of Set 14 | cache creek
# Processing Record 10 of Set 14 | matagami
# Processing Record 11 of Set 14 | bergen
# Processing Record 12 of Set 14 | kushmurun
# Processing Record 13 of Set 14 | deloraine
# Processing Record 14 of Set 14 | rincon
# Processing Record 15 of Set 14 | alice springs
# Processing Record 16 of Set 14 | labytnangi
# Processing Record 17 of Set 14 | yeppoon
# Processing Record 18 of Set 14 | vallee-jonction
# City not found. Skipping...
# Processing Record 19 of Set 14 | benjamin hill
# Processing Record 20 of Set 14 | alofi
# Processing Record 21 of Set 14 | buraydah
# Processing Record 22 of Set 14 | agudos
# Processing Record 23 of Set 14 | yumen
# Processing Record 24 of Set 14 | puerto escondido
# Processing Record 25 of Set 14 | svetlogorsk
# Processing Record 26 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 27 of Set 14 | florianopolis
# Processing Record 28 of Set 14 | kandalaksha
# Processing Record 29 of Set 14 | wodonga
# Processing Record 30 of Set 14 | bambanglipuro
# Processing Record 31 of Set 14 | roebourne
# Processing Record 32 of Set 14 | coroico
# Processing Record 33 of Set 14 | zeya
# Processing Record 34 of Set 14 | arica
# Processing Record 35 of Set 14 | kapuskasing
# Processing Record 36 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 37 of Set 14 | acapulco
# Processing Record 38 of Set 14 | chernyshevskiy
# Processing Record 39 of Set 14 | ust-ordynskiy
# Processing Record 40 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 14 | qingdao
# Processing Record 42 of Set 14 | harper
# Processing Record 43 of Set 14 | hendijan
# City not found. Skipping...
# Processing Record 44 of Set 14 | asau
# Processing Record 45 of Set 14 | aksarka
# Processing Record 46 of Set 14 | condado
# Processing Record 47 of Set 14 | kati
# Processing Record 48 of Set 14 | blagoveshchenka
# Processing Record 49 of Set 14 | yerbogachen
# Processing Record 50 of Set 14 | salalah
# Processing Record 1 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 2 of Set 15 | blythe
# Processing Record 3 of Set 15 | teguldet
# Processing Record 4 of Set 15 | san francisco
# Processing Record 5 of Set 15 | gorontalo
# Processing Record 6 of Set 15 | ulladulla
# Processing Record 7 of Set 15 | umm ruwabah
# City not found. Skipping...
# Processing Record 8 of Set 15 | tual
# Processing Record 9 of Set 15 | sao gabriel da cachoeira
# Processing Record 10 of Set 15 | jalingo
# Processing Record 11 of Set 15 | tongliao
# Processing Record 12 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 15 | rehoboth
# Processing Record 14 of Set 15 | yumbel
# Processing Record 15 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 16 of Set 15 | kathmandu
# Processing Record 17 of Set 15 | ostersund
# Processing Record 18 of Set 15 | oskarshamn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### 7. Add the data to a new DataFrame.

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Omboue      GA  -1.5746    9.2618     70.34        89          50
# 1     New Norfolk      AU -42.7826  147.0587     52.88        77           5
# 2           Aswan      EG  24.0934   32.9070     87.40        21           8
# 3        Tasiilaq      GL  65.6145  -37.6368     39.36        80         100
# 4  Ribeira Grande      PT  38.5167  -28.7000     66.49        81         100
#
#    Wind Speed Current Description
# 0        7.31    scattered clouds
# 1        4.00           clear sky
# 2        8.95           clear sky
# 3        2.15     overcast clouds
# 4       14.00     overcast clouds

# %% [markdown]
# ### 8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
